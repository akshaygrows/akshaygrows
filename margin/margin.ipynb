# %%
import pandas as pd
import sys

sys.path.append('..')
from scripts.postgres_connect import *

# %%
file_location = 'Revenue April-24 File _V3.xlsx'
sheet_name = 'Revenue'

df = pd.read_excel(file_location, sheet_name=sheet_name)

# Now you can work with your modified DataFrame
print(df.head())
# Out:
#             awb  Shipment ID shop_order_number user_name Type  user_id  \
# 0  GS2126985103      5138857            AB-535  Abhishti  SDD      219
# 1  GS1821141297      5084637             54915  Abhishti  SDD      219
# 2  GS1945828791      5023087            AB-528  Abhishti  SDD      219
# 3  GS1083901733      5235387             55343  Abhishti  SDD      219
# 4  GS1940479797      5115796             55034  Abhishti  SDD      219
#
#   shipping_partner shipment_cost_type  drop_pincode Shipping City  ...  \
# 0       Hyperlocal         Hyperlocal        110052         Delhi  ...
# 1       Hyperlocal         Hyperlocal        122002         Delhi  ...
# 2       Hyperlocal         Hyperlocal        110052         Delhi  ...
# 3       Hyperlocal         Hyperlocal        122017         Delhi  ...
# 4       Hyperlocal         Hyperlocal        110046         Delhi  ...
#
#   Ops Main â†’ Warehouse Name Ops Main - Pickup Date Ops Main - Pickuptime  \
# 0                Abhishti_GGN             2024-04-07              10:16:35
# 1                Abhishti_GGN             2024-04-05              10:21:22
# 2                Abhishti_GGN             2024-03-31              11:17:11
# 3                Abhishti_GGN             2024-04-13              10:17:55
# 4                Abhishti_GGN             2024-04-06              10:12:27
#
#    Ops Main - First Ofd Date Ops Main - First Ofd Time  \
# 0                 2024-04-07                  17:03:15
# 1                 2024-04-05                  14:04:06
# 2                 2024-03-31                  15:39:04
# 3                 2024-04-13                  14:33:32
# 4                 2024-04-06                  15:20:25
#
#   Ops Main â†’ Delivertime Ops Main â†’ Rto Delivered Time Weight Source  \
# 0      2024-04-08T17:28:46                             NaN           NaN
# 1      2024-04-05T16:38:11                             NaN           NaN
# 2      2024-04-01T12:50:26                             NaN           NaN
# 3      2024-04-13T15:43:29                             NaN           NaN
# 4      2024-04-06T18:15:44                             NaN           NaN
#
#   Shiprocket_key  Differece
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
#
# [5 rows x 56 columns]

# %%
revenue_df = df[df['shipping_partner'] == 'Hyperlocal']
revenue_df['Shipping City'] = revenue_df['Shipping City'].replace('NCR', 'Delhi')
revenue_df['Warehouse City'] = revenue_df['Warehouse City'].replace('NCR', 'Delhi')
revenue_df.loc[(revenue_df['Warehouse City'] == 'Delhi') & (revenue_df['user_name'] == 'GIVA'), 'Warehouse City'] = 'Bangalore'
revenue_df.head()
# Out:
#             awb  Shipment ID shop_order_number user_name Type  user_id  \
# 0  GS2126985103      5138857            AB-535  Abhishti  SDD      219
# 1  GS1821141297      5084637             54915  Abhishti  SDD      219
# 2  GS1945828791      5023087            AB-528  Abhishti  SDD      219
# 3  GS1083901733      5235387             55343  Abhishti  SDD      219
# 4  GS1940479797      5115796             55034  Abhishti  SDD      219
#
#   shipping_partner shipment_cost_type  drop_pincode Shipping City  ...  \
# 0       Hyperlocal         Hyperlocal        110052         Delhi  ...
# 1       Hyperlocal         Hyperlocal        122002         Delhi  ...
# 2       Hyperlocal         Hyperlocal        110052         Delhi  ...
# 3       Hyperlocal         Hyperlocal        122017         Delhi  ...
# 4       Hyperlocal         Hyperlocal        110046         Delhi  ...
#
#   Ops Main â†’ Warehouse Name Ops Main - Pickup Date Ops Main - Pickuptime  \
# 0                Abhishti_GGN             2024-04-07              10:16:35
# 1                Abhishti_GGN             2024-04-05              10:21:22
# 2                Abhishti_GGN             2024-03-31              11:17:11
# 3                Abhishti_GGN             2024-04-13              10:17:55
# 4                Abhishti_GGN             2024-04-06              10:12:27
#
#    Ops Main - First Ofd Date Ops Main - First Ofd Time  \
# 0                 2024-04-07                  17:03:15
# 1                 2024-04-05                  14:04:06
# 2                 2024-03-31                  15:39:04
# 3                 2024-04-13                  14:33:32
# 4                 2024-04-06                  15:20:25
#
#   Ops Main â†’ Delivertime Ops Main â†’ Rto Delivered Time Weight Source  \
# 0      2024-04-08T17:28:46                             NaN           NaN
# 1      2024-04-05T16:38:11                             NaN           NaN
# 2      2024-04-01T12:50:26                             NaN           NaN
# 3      2024-04-13T15:43:29                             NaN           NaN
# 4      2024-04-06T18:15:44                             NaN           NaN
#
#   Shiprocket_key  Differece
# 0            NaN        NaN
# 1            NaN        NaN
# 2            NaN        NaN
# 3            NaN        NaN
# 4            NaN        NaN
#
# [5 rows x 56 columns]

# %%
revenue_df[revenue_df['Warehouse City']=='NCR']
# Out:
# Empty DataFrame
# Columns: [awb, Shipment ID, shop_order_number, user_name, Type, user_id, shipping_partner, shipment_cost_type, drop_pincode, Shipping City, Warehouse City, LM Hub, FC, Shipper ID, shipping_zone, shipment_status, mop, pickup_date, first_ofd_date, Gap, closure_date, attributed_month, dead_weight, vol_weight, chargeable_weight, client_pricing_key, cod_amount, gmv, shipper wt, Final Weight, base_weight, additional_weight, b_charge, a_charge, cod, cod_per, RTO Multiplier, fuel_surcharge, Client Chargeable Wt (final), Bucket, Add Multiplier Factor, Frieght Charges, COD Charges, RTO Charges, Shipment Charges, Ops Main â†’ Created Date, Ops Main â†’ Warehouse Name, Ops Main - Pickup Date, Ops Main - Pickuptime, Ops Main - First Ofd Date, Ops Main - First Ofd Time, Ops Main â†’ Delivertime, Ops Main â†’ Rto Delivered Time, Weight Source, Shiprocket_key, Differece]
# Index: []
#
# [0 rows x 56 columns]

# %%
revenue_df['Shipment Charges'].sum()

# %% [markdown]
# Cost Calculation

# %%
key_path = 'tunnel-ssh.cer'
conn = get_conn('Yes',key_path)
query_path = 'april_payout.sql'
with open(query_path, 'r') as file:
    custom_query = file.read()

rider_cost_df = pd.read_sql(custom_query,conn)
rider_cost_df['city'] = rider_cost_df['city'].replace('NCR', 'Delhi')
rider_cost_df['warehouse_city']= rider_cost_df['warehouse_city'].replace('NCR','Delhi')
conn.close()
rider_cost_df.head()
# Out:
# Starting Tunnel Started
# Started, getting conn
# Connection Made
#             awb                        task_id dispatch_date    city  \
# 0  GS1655065386  GS1655065386_4H_LM_1714276103    2024-04-28  Mumbai
# 1  GS2079143197  GS2079143197_4H_LM_1714027875    2024-04-25  Mumbai
# 2  GS1172669705  GS1172669705_4H_LM_1713929932    2024-04-24  Mumbai
# 3  GS1620959247  GS1620959247_4H_LM_1713864629    2024-04-23  Mumbai
# 4  GS1511341798  GS1511341798_4H_LM_1713242912    2024-04-16  Mumbai
#
#   warehouse_city          hub                  rider_id  awb_pay     status  \
# 0         Mumbai   DS BOM KRL   DS_BOM_KRL_30062022_001     45.0  COMPLETED
# 1         Mumbai  DS BOM SWRI  DS_BOM_KRL_0310202309_72     29.0  COMPLETED
# 2         Mumbai   DS BOM KRL           Munir_shaikh__3     28.0  COMPLETED
# 3          Delhi  DS BOM THAN       Rohit_9920177567_03     28.0  COMPLETED
# 4         Mumbai   DS BOM KRL  DS_BOM_KRL_22082022_0003     29.0  COMPLETED
#
#   payout_structure
# 0            ORDER
# 1            ORDER
# 2            ORDER
# 3            ORDER
# 4            ORDER

# %%
rider_cost_df['awb_pay'].sum()
# Out:
# 17154236.0

# %%
rider_cost_df['warehouse_city'] = rider_cost_df['warehouse_city'].replace('NCR', 'Delhi')
cost_order_by_lane = rider_cost_df.groupby(['warehouse_city','city'])['awb'].count()
cost_order_by_lane = cost_order_by_lane.reset_index()
cost_order_by_city = rider_cost_df.groupby(['city'])['awb'].count()
cost_order_by_city = cost_order_by_city.reset_index()

# %%
cost_order_by_lane
# Out:
#   warehouse_city       city     awb
# 0      Bangalore  Bangalore  147975
# 1      Bangalore  Hyderabad   22459
# 2          Delhi  Bangalore    5086
# 3          Delhi      Delhi  143989
# 4          Delhi  Hyderabad    2081
# 5          Delhi     Jaipur   10978
# 6          Delhi     Mumbai    4331
# 7      Hyderabad  Hyderabad   56545
# 8         Mumbai     Mumbai   65869

# %%
# Filter revenue_df for rows where 'shipment_status' is 'Delivered'
revenue_delivered = revenue_df[revenue_df['shipment_status'] == 'Delivered']

# Check for awb values in revenue_df (delivered orders) not in cost_df
awb_in_revenue_not_in_cost = revenue_delivered[~revenue_delivered['awb'].isin(rider_cost_df['awb'])]['awb']

# Check for awb values in cost_df not in revenue_df (delivered orders)
awb_in_cost_not_in_revenue = rider_cost_df[~rider_cost_df['awb'].isin(revenue_delivered['awb'])]['awb']

print("AWB values in revenue_df (Delivered orders) not in cost_df:")
print(awb_in_revenue_not_in_cost)

print("\nAWB values in cost_df not in revenue_df (Delivered orders):")
print(awb_in_cost_not_in_revenue)
# Out:
# AWB values in revenue_df (Delivered orders) not in cost_df:
# 224       GS1944381658
# 901       GS1309780941
# 1294      GS1531974088
# 1913      GS1190013051
# 3264      GS1371298465
#               ...
# 495203    GS1748924969
# 495364    GS1843021107
# 495636    GS1498978650
# 495684    GS1370718653
# 495759    GS1990377814
# Name: awb, Length: 849, dtype: object
#
# AWB values in cost_df not in revenue_df (Delivered orders):
# 6548       GS2129978346
# 70909     BZPPL00264950
# 78223     BZPPL00268114
# 78617     BZPPL00263442
# 107295    BZPPL00232382
# 156511     GS1568822488
# 166002     GS1607460728
# 172107     GS2082344653
# 190388     GS1754036906
# 205458     GS1285848945
# 221791     GS2113476927
# 227092     GS1029693724
# 270602     GS1510049004
# 287475     GS1735343902
# 290440     GS1629381925
# 421694     GS1717536986
# 428558     GS2019403325
# 434124     GS1717185818
# 455923     GS1221987140
# Name: awb, dtype: object

# %%
# Filter revenue_df for only the 'awb' values not in cost_df
revenue_filtered = revenue_df[revenue_df['awb'].isin(awb_in_revenue_not_in_cost)]

# Group by 'shipment status' and count the occurrences of 'awb'
awb_counts_by_status = revenue_filtered.groupby('shipment_status')['awb'].count()

print('awb in revenue which are not in cost and are delivered \n' ,awb_counts_by_status)
# Out:
# awb in revenue which are not in cost and are delivered
#  shipment_status
# Delivered    849
# Name: awb, dtype: int64

# %%
awb_counts_by_city = revenue_filtered.groupby('Shipping City')['awb'].count()
print('awb in revenue which are not in cost and are delivered by city\n' ,awb_counts_by_city)
# Out:
# awb in revenue which are not in cost and are delivered by city
#  Shipping City
# Bangalore    364
# Delhi        206
# Hyderabad    151
# Jaipur         2
# Mumbai       106
# NCR           20
# Name: awb, dtype: int64

# %%
print('columns in rider cost\n',rider_cost_df.columns)
print('columns in revenue\n',revenue_df.columns)
# Out:
# columns in rider cost
#  Index(['awb', 'task_id', 'dispatch_date', 'city', 'warehouse_city', 'hub',
#        'rider_id', 'awb_pay', 'status', 'payout_structure'],
#       dtype='object')
# columns in revenue
#  Index(['awb', 'Shipment ID', 'shop_order_number', 'user_name', 'Type',
#        'user_id', 'shipping_partner', 'shipment_cost_type', 'drop_pincode',
#        'Shipping City', 'Warehouse City', 'LM Hub', 'FC', 'Shipper ID',
#        'shipping_zone', 'shipment_status', 'mop', 'pickup_date',
#        'first_ofd_date', 'Gap', 'closure_date', 'attributed_month',
#        'dead_weight', 'vol_weight', 'chargeable_weight', 'client_pricing_key',
#        'cod_amount', 'gmv', 'shipper wt', 'Final Weight', 'base_weight',
#        'additional_weight', 'b_charge', 'a_charge', 'cod', 'cod_per',
#        'RTO Multiplier', 'fuel_surcharge', 'Client Chargeable Wt (final)',
#        'Bucket', 'Add Multiplier Factor', 'Frieght Charges', 'COD Charges',
#        'RTO Charges', 'Shipment Charges', 'Ops Main â†’ Created Date',
#        'Ops Main â†’ Warehouse Name', 'Ops Main - Pickup Date',
#        'Ops Main - Pickuptime', 'Ops Main - First Ofd Date',
#        'Ops Main - First Ofd Time', 'Ops Main â†’ Delivertime',
#        'Ops Main â†’ Rto Delivered Time', 'Weight Source', 'Shiprocket_key',
#        'Differece', 'shipping_city'],
#       dtype='object')

# %% [markdown]
# ### Adding MM Cost in Cost

# %%
df_mm_lane = pd.read_csv('mm-cost.csv',header='infer')
df_mm_lane.drop(columns=['Orders (computable)'],inplace = True)
df_mm_lane['Cost'] = df_mm_lane['Cost'].str.replace(',', '').astype(int)
df_mm_lane.head()
# Out:
#         Month Warehouse City Shipping City Vendor Name     Cost   Lane Type
# 0  01/04/2024      Bangalore     Hyderabad     Rippler   712478   Intercity
# 1  01/04/2024      Bangalore     Bangalore    Yellappa  1785760  Hyperlocal
# 2  01/04/2024          Delhi     Hyderabad     Rippler   296703   Intercity
# 3  01/04/2024          Delhi        Mumbai     Rippler   395575   Intercity
# 4  01/04/2024          Delhi     Bangalore     Rippler   516988   Intercity

# %% [markdown]
# ### getting mm fm cost by lane

# %%
cost_order_by_lane.head()
# Out:
#   warehouse_city       city     awb
# 0      Bangalore  Bangalore  147975
# 1      Bangalore  Hyderabad   22459
# 2          Delhi  Bangalore    5086
# 3          Delhi      Delhi  143989
# 4          Delhi  Hyderabad    2081

# %%
cost_order_by_lane['self_orders'] = cost_order_by_lane['warehouse_city'] == cost_order_by_lane['city']
cost_order_by_lane['intercity_orders'] = cost_order_by_lane['warehouse_city'] != cost_order_by_lane['city']
cost_order_by_lane
# Out:
#   warehouse_city       city     awb  self_orders  intercity_orders
# 0      Bangalore  Bangalore  147975         True             False
# 1      Bangalore  Hyderabad   22459        False              True
# 2          Delhi  Bangalore    5086        False              True
# 3          Delhi      Delhi  143989         True             False
# 4          Delhi  Hyderabad    2081        False              True
# 5          Delhi     Jaipur   10978        False              True
# 6          Delhi     Mumbai    4331        False              True
# 7      Hyderabad  Hyderabad   56545         True             False
# 8         Mumbai     Mumbai   65869         True             False

# %%
self_orders_sum = cost_order_by_lane[cost_order_by_lane['self_orders']].groupby('warehouse_city')['awb'].sum().reset_index()
intercity_orders_sum = cost_order_by_lane[cost_order_by_lane['intercity_orders']].groupby('warehouse_city')['awb'].sum().reset_index()

# Merge the results
mm_orders = pd.merge(self_orders_sum, intercity_orders_sum, on='warehouse_city', how='outer', suffixes=('_self_orders', '_intercity_orders')).fillna(0)

# Rename columns for clarity
mm_orders.columns = ['warehouse_city', 'awb_self_orders', 'awb_intercity_orders']

print(mm_orders)
# Out:
#   warehouse_city  awb_self_orders  awb_intercity_orders
# 0      Bangalore           147975               22459.0
# 1          Delhi           143989               22476.0
# 2      Hyderabad            56545                   0.0
# 3         Mumbai            65869                   0.0

# %%
df_mm_lane_self = df_mm_lane[df_mm_lane['Lane Type']=='Hyperlocal']
df_mm_self = df_mm_lane_self.groupby('Warehouse City').aggregate({'Cost':'sum'}).reset_index()
df_mm_self.columns = ['warehouse_city','mm_cost']
df_mm_self
# Out:
#   warehouse_city  mm_cost
# 0      Bangalore  1785760
# 1          Delhi  1751510
# 2      Hyderabad   283123
# 3         Mumbai   538500

# %%
df_mm_self_cpo = mm_orders.merge(df_mm_self,on='warehouse_city',how='left')
df_mm_self_cpo['self_mm_fm_cpo']=2*df_mm_self_cpo['mm_cost']/(2*df_mm_self_cpo['awb_self_orders'] + df_mm_self_cpo['awb_intercity_orders'])
df_mm_self_cpo['intercity_fm_cpo']=df_mm_self_cpo['mm_cost']/(2*df_mm_self_cpo['awb_self_orders'] + df_mm_self_cpo['awb_intercity_orders'])
df_mm_self_cpo
# Out:
#   warehouse_city  awb_self_orders  awb_intercity_orders  mm_cost  \
# 0      Bangalore           147975               22459.0  1785760
# 1          Delhi           143989               22476.0  1751510
# 2      Hyderabad            56545                   0.0   283123
# 3         Mumbai            65869                   0.0   538500
#
#    self_mm_fm_cpo  intercity_fm_cpo
# 0       11.216768          5.608384
# 1       11.283540          5.641770
# 2        5.007039          2.503519
# 3        8.175318          4.087659

# %%
df_mm_lane.columns = ['month','warehouse_city','shipping_city','vendor_name','cost','lane_type']
cost_order_by_lane.columns = ['warehouse_city','shipping_city','awb','self_orders','intercity_orders']
intercity_orders_by_lane = cost_order_by_lane[cost_order_by_lane['intercity_orders'] == True]
df_mm_intercity_cpo = intercity_orders_by_lane.merge(df_mm_lane,on=['warehouse_city','shipping_city'],how='left')
df_mm_intercity_cpo['intercity_mm_cpo'] = df_mm_intercity_cpo['cost']/df_mm_intercity_cpo['awb']
df_mm_intercity_cpo
# Out:
#   warehouse_city shipping_city    awb  self_orders  intercity_orders  \
# 0      Bangalore     Hyderabad  22459        False              True
# 1          Delhi     Bangalore   5086        False              True
# 2          Delhi     Hyderabad   2081        False              True
# 3          Delhi        Jaipur  10978        False              True
# 4          Delhi        Mumbai   4331        False              True
#
#         month vendor_name    cost  lane_type  intercity_mm_cpo
# 0  01/04/2024     Rippler  712478  Intercity         31.723496
# 1  01/04/2024     Rippler  516988  Intercity        101.649233
# 2  01/04/2024     Rippler  296703  Intercity        142.577126
# 3  01/04/2024         NaN  154562  Intercity         14.079249
# 4  01/04/2024     Rippler  395575  Intercity         91.335719

# %%
hyperlocal_df = rider_cost_df[rider_cost_df['warehouse_city']==rider_cost_df['city']]
hyperlocal_df = hyperlocal_df.merge(df_mm_self_cpo[['warehouse_city','self_mm_fm_cpo']], on ='warehouse_city', how='left')
hyperlocal_df['intercity_fm_cpo'] = 0
hyperlocal_df['intercity_mm_cpo'] = 0

intercity_df = rider_cost_df[rider_cost_df['warehouse_city']!=rider_cost_df['city']]
intercity_df = intercity_df.merge(df_mm_self_cpo[['warehouse_city','intercity_fm_cpo']], on ='warehouse_city', how='left')
intercity_df = intercity_df.merge(df_mm_intercity_cpo[['warehouse_city','shipping_city','intercity_mm_cpo']], left_on = ['warehouse_city','city'], right_on=['warehouse_city','shipping_city'],how='left')
intercity_df['self_mm_fm_cpo'] = 0

final_cost_df = pd.concat([hyperlocal_df, intercity_df]).drop(columns=['shipping_city']).reset_index()
final_cost_df['total_mm_cost'] = final_cost_df['self_mm_fm_cpo']+final_cost_df['intercity_mm_cpo']+final_cost_df['intercity_fm_cpo']
final_cost_df.drop(columns=['self_mm_fm_cpo','intercity_mm_cpo','intercity_fm_cpo'],inplace=True)

print(final_cost_df)
# Out:
#         index           awb                        task_id dispatch_date  \
# 0           0  GS1655065386  GS1655065386_4H_LM_1714276103    2024-04-28
# 1           1  GS2079143197  GS2079143197_4H_LM_1714027875    2024-04-25
# 2           2  GS1172669705  GS1172669705_4H_LM_1713929932    2024-04-24
# 3           3  GS1511341798  GS1511341798_4H_LM_1713242912    2024-04-16
# 4           4  GS2014266159  GS2014266159_4H_LM_1712115454    2024-04-03
# ...       ...           ...                            ...           ...
# 459312  44934  GS1729020522  GS1729020522_4H_LM_1712047044    2024-04-02
# 459313  44935  GS2098484046  GS2098484046_4H_LM_1712384891    2024-04-06
# 459314  44936  GS1559659077  GS1559659077_4H_LM_1713324981    2024-04-17
# 459315  44937  GS1111263574  GS1111263574_4H_LM_1712230270    2024-04-04
# 459316  44938  GS1583128901  GS1583128901_4H_LM_1713333626    2024-04-17
#
#              city warehouse_city             hub                     rider_id  \
# 0          Mumbai         Mumbai      DS BOM KRL      DS_BOM_KRL_30062022_001
# 1          Mumbai         Mumbai     DS BOM SWRI     DS_BOM_KRL_0310202309_72
# 2          Mumbai         Mumbai      DS BOM KRL              Munir_shaikh__3
# 3          Mumbai         Mumbai      DS BOM KRL     DS_BOM_KRL_22082022_0003
# 4          Mumbai         Mumbai      DS BOM KRL      manjur_Kasam_qureshi_17
# ...           ...            ...             ...                          ...
# 459312  Bangalore          Delhi      DS BLR MTH  Shivalingaiah_8296452339_01
# 459313  Bangalore          Delhi  CMRJ-Franchise         Dilip_9742153525_032
# 459314  Bangalore          Delhi  BLDR-Franchise            MV_9353062560_033
# 459315  Bangalore          Delhi  CMRJ-Franchise         Sameer_7829665775_02
# 459316  Bangalore          Delhi  YLHK-Franchise         Manoj_7022220172_035
#
#         awb_pay     status payout_structure  total_mm_cost
# 0          45.0  COMPLETED            ORDER       8.175318
# 1          29.0  COMPLETED            ORDER       8.175318
# 2          28.0  COMPLETED            ORDER       8.175318
# 3          29.0  COMPLETED            ORDER       8.175318
# 4          29.0  COMPLETED            ORDER       8.175318
# ...         ...        ...              ...            ...
# 459312     40.0  COMPLETED            FIXED     107.291003
# 459313     38.0  COMPLETED            ORDER     107.291003
# 459314     80.0  COMPLETED            ORDER     107.291003
# 459315     38.0  COMPLETED            ORDER     107.291003
# 459316     38.0  COMPLETED            ORDER     107.291003
#
# [459317 rows x 12 columns]

# %%
conn = get_conn('Yes',key_path)
query_path = 'fuel_payout.sql'
with open(query_path, 'r') as file:
    custom_query = file.read()

fuel_cost = pd.read_sql(custom_query,conn)
conn.close()
fuel_cost.head()
# Out:
# Starting Tunnel Started
# Started, getting conn
# Connection Made
#      node_name  tour_date            locus_rider_id  fuel_payout_automation  \
# 0  DS BLR BOMM 2024-04-01  Abdul_manaf_2_1701754675                    True
# 1  DS BLR BOMM 2024-04-01             Abhishek_MS_2                    True
# 2  DS BLR BOMM 2024-04-01            Aejaz_pasha__2                    True
# 3  DS BLR BOMM 2024-04-01      Ananda_8660619030_02                    True
# 4  DS BLR BOMM 2024-04-01              Anil_nayak_2                    True
#
#      rider_name  final_distance  final_fuel_payout  tours  assigned_orders  \
# 0   Abdul manaf            24.0               72.0      2             40.0
# 1   Abhishek MS            27.0               81.0      1             31.0
# 2  Aejaz pasha             52.0              156.0      1             54.0
# 3      Ananda M            23.0               69.0      1             13.0
# 4    Anil nayak            13.0               39.0      2             15.0
#
#    delivered_orders  ...  fuel_rate  distance_limit  sort_codes  \
# 0              38.0  ...          3             100    BLR/JPNR
# 1              27.0  ...          3             100    BLR/JPNR
# 2              49.0  ...          3             100    BLR/JPNR
# 3              11.0  ...          3             100    BLR/JPNR
# 4              13.0  ...          3             100    BLR/JPNR
#
#                                              address   contact_name  \
# 0  No. L/F , 2/1, B.D.A Flats 2nd Main, Bannergha...  Biswojit Jena
# 1  No. L/F , 2/1, B.D.A Flats 2nd Main, Bannergha...  Biswojit Jena
# 2  No. L/F , 2/1, B.D.A Flats 2nd Main, Bannergha...  Biswojit Jena
# 3  No. L/F , 2/1, B.D.A Flats 2nd Main, Bannergha...  Biswojit Jena
# 4  No. L/F , 2/1, B.D.A Flats 2nd Main, Bannergha...  Biswojit Jena
#
#    contact_phone node_type  locus_home_base_id  city_name actual_city_name
# 0     9066859089    lm_hub           blr-lmh-2  Bangalore        Bangalore
# 1     9066859089    lm_hub           blr-lmh-2  Bangalore        Bangalore
# 2     9066859089    lm_hub           blr-lmh-2  Bangalore        Bangalore
# 3     9066859089    lm_hub           blr-lmh-2  Bangalore        Bangalore
# 4     9066859089    lm_hub           blr-lmh-2  Bangalore        Bangalore
#
# [5 rows x 27 columns]

# %%
fuel_cost2 = fuel_cost.groupby('locus_rider_id').aggregate({
    'final_fuel_payout':'sum',
    'delivered_orders':'sum'
}).reset_index()
fuel_cost2['fuel_cpo'] = fuel_cost2['final_fuel_payout']/fuel_cost2['delivered_orders']

# %%
final_cost_df2 = final_cost_df.merge(fuel_cost2[['locus_rider_id','fuel_cpo']],left_on='rider_id',right_on='locus_rider_id',how='left').reset_index()
final_cost_df2 = final_cost_df2.drop(columns=['locus_rider_id','level_0','index'])
final_cost_df2['vendor_comm'] = final_cost_df2['awb_pay']*0.06
final_cost_df2=final_cost_df2.fillna(0)
final_cost_df2['total_cost'] = final_cost_df2['awb_pay']+final_cost_df2['total_mm_cost']+final_cost_df2['fuel_cpo']+final_cost_df2['vendor_comm']
final_cost_df2.head()
# Out:
#             awb                        task_id dispatch_date    city  \
# 0  GS1655065386  GS1655065386_4H_LM_1714276103    2024-04-28  Mumbai
# 1  GS2079143197  GS2079143197_4H_LM_1714027875    2024-04-25  Mumbai
# 2  GS1172669705  GS1172669705_4H_LM_1713929932    2024-04-24  Mumbai
# 3  GS1511341798  GS1511341798_4H_LM_1713242912    2024-04-16  Mumbai
# 4  GS2014266159  GS2014266159_4H_LM_1712115454    2024-04-03  Mumbai
#
#   warehouse_city          hub                  rider_id  awb_pay     status  \
# 0         Mumbai   DS BOM KRL   DS_BOM_KRL_30062022_001     45.0  COMPLETED
# 1         Mumbai  DS BOM SWRI  DS_BOM_KRL_0310202309_72     29.0  COMPLETED
# 2         Mumbai   DS BOM KRL           Munir_shaikh__3     28.0  COMPLETED
# 3         Mumbai   DS BOM KRL  DS_BOM_KRL_22082022_0003     29.0  COMPLETED
# 4         Mumbai   DS BOM KRL   manjur_Kasam_qureshi_17     29.0  COMPLETED
#
#   payout_structure  total_mm_cost   fuel_cpo  vendor_comm  total_cost
# 0            ORDER       8.175318  12.000000         2.70   67.875318
# 1            ORDER       8.175318   3.771812         1.74   42.687130
# 2            ORDER       8.175318   5.770764         1.68   43.626082
# 3            ORDER       8.175318   5.727545         1.74   44.642863
# 4            ORDER       8.175318   4.306959         1.74   43.222277

# %%
final_cost_df2.groupby('city').aggregate({
    'awb_pay':'sum',
    'total_mm_cost':'sum',
    'fuel_cpo':'sum',
    'vendor_comm':'sum',
    'total_cost':'sum'
    }).to_csv('total_cost.csv')

# %% [markdown]
# ## Margin Calculation

# %%
# Perform left join on revenue_df and cost_df using 'awb' as the key
merged_df = revenue_df.merge(final_cost_df2, on='awb', how='left')

# Select useful columns from merged_df
result_df = merged_df[['awb','user_name','rider_id','drop_pincode','Shipping City', 'shipment_status', 'total_cost','Shipment Charges','Warehouse City']]

print(result_df)
# Out:
#                  awb user_name                   rider_id  drop_pincode  \
# 0       GS2126985103  Abhishti        amit_9910567547_028        110052
# 1       GS1821141297  Abhishti               Ajay_VLS_1_5        122002
# 2       GS1945828791  Abhishti      Lokesh_8882951426_034        110052
# 3       GS1083901733  Abhishti               Ajay_VLS_1_5        122017
# 4       GS1940479797  Abhishti  DS_NCT_DWRK_0313202310_15        110046
# ...              ...       ...                        ...           ...
# 493759  GS1314127766    Voylla                Vijender__5        110009
# 493760  GS1224606068    Voylla                Vijender__5        110009
# 493761  GS1609354812    Voylla            Kunal_chawla__5        122002
# 493762  GS2078607672      Wyzr           md_7259370241_07        560024
# 493763  GS1414292705      Wyzr                        NaN        121007
#
#        Shipping City shipment_status  total_cost  Shipment Charges  \
# 0              Delhi       Delivered   43.083540          130.0000
# 1              Delhi       Delivered   67.373946           60.2138
# 2              Delhi       Delivered   74.883540          676.0000
# 3              Delhi       Delivered   82.213946           26.0000
# 4              Delhi       Delivered   58.733752           26.0000
# ...              ...             ...         ...               ...
# 493759         Delhi       Delivered   45.203540           49.0000
# 493760         Delhi       Delivered   45.203540           49.0000
# 493761         Delhi       Delivered   56.403663           26.0000
# 493762     Bangalore       Delivered   46.502879           60.0000
# 493763         Delhi   RTO Delivered         NaN           80.0000
#
#        Warehouse City
# 0               Delhi
# 1               Delhi
# 2               Delhi
# 3               Delhi
# 4               Delhi
# ...               ...
# 493759          Delhi
# 493760          Delhi
# 493761          Delhi
# 493762      Bangalore
# 493763          Delhi
#
# [493764 rows x 9 columns]

# %%
#adding margin column
margin_df = result_df[result_df['Shipping City'].notnull()]
margin_df = margin_df.fillna(0)
margin_df['margin'] = margin_df['Shipment Charges'] - margin_df['total_cost']
print(margin_df)
# Out:
#                  awb user_name                   rider_id  drop_pincode  \
# 0       GS2126985103  Abhishti        amit_9910567547_028        110052
# 1       GS1821141297  Abhishti               Ajay_VLS_1_5        122002
# 2       GS1945828791  Abhishti      Lokesh_8882951426_034        110052
# 3       GS1083901733  Abhishti               Ajay_VLS_1_5        122017
# 4       GS1940479797  Abhishti  DS_NCT_DWRK_0313202310_15        110046
# ...              ...       ...                        ...           ...
# 493759  GS1314127766    Voylla                Vijender__5        110009
# 493760  GS1224606068    Voylla                Vijender__5        110009
# 493761  GS1609354812    Voylla            Kunal_chawla__5        122002
# 493762  GS2078607672      Wyzr           md_7259370241_07        560024
# 493763  GS1414292705      Wyzr                          0        121007
#
#        Shipping City shipment_status  total_cost  Shipment Charges  \
# 0              Delhi       Delivered   43.083540          130.0000
# 1              Delhi       Delivered   67.373946           60.2138
# 2              Delhi       Delivered   74.883540          676.0000
# 3              Delhi       Delivered   82.213946           26.0000
# 4              Delhi       Delivered   58.733752           26.0000
# ...              ...             ...         ...               ...
# 493759         Delhi       Delivered   45.203540           49.0000
# 493760         Delhi       Delivered   45.203540           49.0000
# 493761         Delhi       Delivered   56.403663           26.0000
# 493762     Bangalore       Delivered   46.502879           60.0000
# 493763         Delhi   RTO Delivered    0.000000           80.0000
#
#        Warehouse City      margin
# 0               Delhi   86.916460
# 1               Delhi   -7.160146
# 2               Delhi  601.116460
# 3               Delhi  -56.213946
# 4               Delhi  -32.733752
# ...               ...         ...
# 493759          Delhi    3.796460
# 493760          Delhi    3.796460
# 493761          Delhi  -30.403663
# 493762      Bangalore   13.497121
# 493763          Delhi   80.000000
#
# [493580 rows x 10 columns]

# %%
margin_df[margin_df['Shipping City']=='NCR']
# Out:
# Empty DataFrame
# Columns: [awb, user_name, rider_id, drop_pincode, Shipping City, shipment_status, total_cost, Shipment Charges, Warehouse City, margin]
# Index: []

# %% [markdown]
# ## Client Level Margin

# %%
client_margin = margin_df.groupby(['user_name', 'Shipping City']).agg({
    'awb': pd.Series.nunique,
    'Shipment Charges': 'sum',
    'total_cost': 'sum',
    'margin': 'sum'
}).rename(columns={'awb': 'orders'}).reset_index()

print(client_margin)
# Out:
#                  user_name Shipping City  orders  Shipment Charges  \
# 0    ANS Digital Pvt. Ltd.     Bangalore      88       26555.90500
# 1    ANS Digital Pvt. Ltd.         Delhi     426       20733.81020
# 2    ANS Digital Pvt. Ltd.        Mumbai     248       13077.54420
# 3                 Abhishti         Delhi      66        7462.10350
# 4               Bebodywise     Bangalore    5416      207883.45000
# ..                     ...           ...     ...               ...
# 158        organic harvest         Delhi    9891      349428.24000
# 159        organic harvest        Jaipur     210        7233.00000
# 160        organic harvest        Mumbai     915       30431.00000
# 161             trueBrowns         Delhi    1459       83559.49475
# 162             trueBrowns        Mumbai      39        1354.72150
#
#         total_cost        margin
# 0      5373.674909  21182.230091
# 1     18053.449133   2680.361067
# 2     13394.950143   -317.405943
# 3      3168.226357   4293.877143
# 4    232312.950818 -24429.500818
# ..             ...           ...
# 158  423419.428188 -73991.188188
# 159   14399.834369  -7166.834369
# 160   48389.858491 -17958.858491
# 161   78778.458444   4781.036306
# 162    1784.104326   -429.382826
#
# [163 rows x 6 columns]

# %%
client_margin.to_excel('April-Margin-by-client.xlsx')

# %% [markdown]
# ## Pincode Level Margin

# %%
pincode_margin = margin_df.groupby(['Shipping City','drop_pincode']).agg({
    'awb': pd.Series.nunique,
    'Shipment Charges': 'sum',
    'total_cost': 'sum',
    'margin': 'sum'
}).rename(columns={'awb': 'orders'}).reset_index()

print(pincode_margin)
# Out:
#     Shipping City  drop_pincode  orders  Shipment Charges    total_cost  \
# 0       Bangalore        560001    1531      95453.352575  81071.575033
# 1       Bangalore        560002     324      26308.655210  17459.018095
# 2       Bangalore        560003     805      52111.028375  38461.914837
# 3       Bangalore        560004    1045      69742.015565  57430.110711
# 4       Bangalore        560005    1491      97251.328045  76205.640905
# ..            ...           ...     ...               ...           ...
# 433        Mumbai        400615    1519      90663.492125  85331.594339
# 434        Mumbai        400617       2         58.000000     57.754272
# 435        Mumbai        401105       1        106.500000      0.000000
# 436        Mumbai        401107       1         37.500000      0.000000
# 437        Mumbai        421301       1         37.500000      0.000000
#
#            margin
# 0    14381.777542
# 1     8849.637115
# 2    13649.113538
# 3    12311.904854
# 4    21045.687140
# ..            ...
# 433   5331.897786
# 434      0.245728
# 435    106.500000
# 436     37.500000
# 437     37.500000
#
# [438 rows x 6 columns]

# %%
pincode_margin.to_excel('April-Margin-by-pincode.xlsx', index=False)

# %% [markdown]
# ## Rider Level Margin

# %%
rto_data = result_df[pd.isnull(result_df['rider_id'])]
rto_data.head()
# Out:
#              awb user_name rider_id  drop_pincode Shipping City  \
# 6   GS1724934467  Abhishti      NaN        110018         Delhi
# 8   GS1990688059  Abhishti      NaN        110063         Delhi
# 13  GS1131336277  Abhishti      NaN        110062         Delhi
# 17  GS1883495065  Abhishti      NaN        110010         Delhi
# 23  GS1605411512  Abhishti      NaN        110026         Delhi
#
#    shipment_status  total_cost  Shipment Charges Warehouse City
# 6    RTO Delivered         NaN              52.0          Delhi
# 8    RTO Delivered         NaN              52.0          Delhi
# 13   RTO Delivered         NaN              52.0          Delhi
# 17   RTO Delivered         NaN              52.0          Delhi
# 23   RTO Delivered         NaN              52.0          Delhi

# %%
rto_data['Shipment Charges'].sum()
# Out:
# 3050676.32015

# %%
rto_by_city = rto_data.groupby('Shipping City').aggregate({
    'awb':'count',
    'Shipment Charges':'sum'
}).reset_index()
rto_by_city.head()
# Out:
#   Shipping City    awb  Shipment Charges
# 0     Bangalore   8557      6.582721e+05
# 1         Delhi  13714      1.335845e+06
# 2     Hyderabad   6613      5.550782e+05
# 3        Jaipur    587      9.132742e+04
# 4        Mumbai   4839      3.970889e+05

# %%
result_df.head()
# Out:
#             awb user_name                   rider_id  drop_pincode  \
# 0  GS2126985103  Abhishti        amit_9910567547_028        110052
# 1  GS1821141297  Abhishti               Ajay_VLS_1_5        122002
# 2  GS1945828791  Abhishti      Lokesh_8882951426_034        110052
# 3  GS1083901733  Abhishti               Ajay_VLS_1_5        122017
# 4  GS1940479797  Abhishti  DS_NCT_DWRK_0313202310_15        110046
#
#   Shipping City shipment_status  total_cost  Shipment Charges Warehouse City
# 0         Delhi       Delivered   43.083540          130.0000          Delhi
# 1         Delhi       Delivered   67.373946           60.2138          Delhi
# 2         Delhi       Delivered   74.883540          676.0000          Delhi
# 3         Delhi       Delivered   82.213946           26.0000          Delhi
# 4         Delhi       Delivered   58.733752           26.0000          Delhi

# %%
rider_data = result_df[pd.notnull(result_df['rider_id'])]
rider_margin = rider_data.groupby(['Shipping City','rider_id']).aggregate({
    'awb':'count',
    'Shipment Charges':'sum',
    'total_cost':'sum'
}).rename(columns={'awb':'orders'}).reset_index()
rider_margin.head()
# Out:
#   Shipping City                          rider_id  orders  Shipment Charges  \
# 0     Bangalore  8ba2a9c2388246c39c37705b4d535b58    1698     107128.442380
# 1     Bangalore               AJAY_7337775314_018    1464      78029.538750
# 2     Bangalore                  A_9876543218_010     584      34535.825925
# 3     Bangalore                       A_Mithun_10     400      26596.039880
# 4     Bangalore                      A_SANTHOSH_1    1074      61892.390700
#
#      total_cost
# 0  92972.759931
# 1  81789.512513
# 2  31378.677421
# 3  22340.572398
# 4  40056.750145

# %%
rider_margin['Shipment Charges'].sum()
# Out:
# 29108178.951674998

# %%
rider_city_rto = rider_margin.groupby('Shipping City').aggregate({'orders':'sum'})
by_city_rto_charges = rider_city_rto.merge(rto_by_city,on='Shipping City',how='left')
by_city_rto_charges['rto_rpo'] = by_city_rto_charges['Shipment Charges']/by_city_rto_charges['orders']
by_city_rto_charges['rto_apo'] = by_city_rto_charges['awb']/by_city_rto_charges['orders']
by_city_rto_charges
# Out:
#   Shipping City  orders    awb  Shipment Charges   rto_rpo   rto_apo
# 0     Bangalore  153056   8557      6.582721e+05  4.300858  0.055908
# 1         Delhi  143986  13714      1.335845e+06  9.277600  0.095245
# 2     Hyderabad   81053   6613      5.550782e+05  6.848337  0.081589
# 3        Jaipur   10976    587      9.132742e+04  8.320647  0.053480
# 4        Mumbai   70199   4839      3.970889e+05  5.656618  0.068933

# %%
rider_margin2 = rider_margin.merge(by_city_rto_charges[['Shipping City','rto_rpo','rto_apo']],on='Shipping City',how='left')
rider_margin2
# Out:
#      Shipping City                          rider_id  orders  \
# 0        Bangalore  8ba2a9c2388246c39c37705b4d535b58    1698
# 1        Bangalore               AJAY_7337775314_018    1464
# 2        Bangalore                  A_9876543218_010     584
# 3        Bangalore                       A_Mithun_10     400
# 4        Bangalore                      A_SANTHOSH_1    1074
# ...            ...                               ...     ...
# 1176        Mumbai              tejas_9867636289_039     246
# 1177        Mumbai               tejes_8879369059_03     107
# 1178        Mumbai             vaibhav_8850386939_03     304
# 1179        Mumbai               vijay_9082672705_03      17
# 1180        Mumbai              vishnu_9930964208_03      28
#
#       Shipment Charges    total_cost   rto_rpo   rto_apo
# 0        107128.442380  92972.759931  4.300858  0.055908
# 1         78029.538750  81789.512513  4.300858  0.055908
# 2         34535.825925  31378.677421  4.300858  0.055908
# 3         26596.039880  22340.572398  4.300858  0.055908
# 4         61892.390700  40056.750145  4.300858  0.055908
# ...                ...           ...       ...       ...
# 1176      13840.740775  16820.936834  5.656618  0.068933
# 1177       5865.191500   8631.514191  5.656618  0.068933
# 1178      59212.337880  32258.910857  5.656618  0.068933
# 1179        827.000000   1346.320400  5.656618  0.068933
# 1180       1829.150500   1995.215409  5.656618  0.068933
#
# [1181 rows x 7 columns]

# %%
rider_margin2['total_charges'] = rider_margin2['orders']*rider_margin2['rto_rpo']+rider_margin2['Shipment Charges']
rider_margin2['total_orders'] = rider_margin2['orders']*rider_margin2['rto_apo']+rider_margin2['orders']
rider_margin2 = rider_margin2.drop(columns=['Shipment Charges','rto_rpo','rto_apo','orders'])
rider_margin2['margin'] = rider_margin2['total_charges'] - rider_margin2['total_cost']
rider_margin2.head()
# Out:
#   Shipping City                          rider_id    total_cost  \
# 0     Bangalore  8ba2a9c2388246c39c37705b4d535b58  92972.759931
# 1     Bangalore               AJAY_7337775314_018  81789.512513
# 2     Bangalore                  A_9876543218_010  31378.677421
# 3     Bangalore                       A_Mithun_10  22340.572398
# 4     Bangalore                      A_SANTHOSH_1  40056.750145
#
#    total_charges  total_orders        margin
# 0  114431.299076   1792.931176  21458.539145
# 1   84325.994700   1545.848787   2536.482186
# 2   37047.526932    616.650063   5668.849512
# 3   28316.383036    422.363057   5975.810638
# 4   66511.512073   1134.044807  26454.761928

# %%
rider_margin2.rename(columns={'Shipping City':'shipping_city'},inplace=True)
rider_margin2.head()
# Out:
#   shipping_city                          rider_id    total_cost  \
# 0     Bangalore  8ba2a9c2388246c39c37705b4d535b58  92972.759931
# 1     Bangalore               AJAY_7337775314_018  81789.512513
# 2     Bangalore                  A_9876543218_010  31378.677421
# 3     Bangalore                       A_Mithun_10  22340.572398
# 4     Bangalore                      A_SANTHOSH_1  40056.750145
#
#    total_charges  total_orders        margin
# 0  114431.299076   1792.931176  21458.539145
# 1   84325.994700   1545.848787   2536.482186
# 2   37047.526932    616.650063   5668.849512
# 3   28316.383036    422.363057   5975.810638
# 4   66511.512073   1134.044807  26454.761928

# %%
rider_margin2.to_excel('April-Margin-by-rider.xlsx',index=False)

# %% [markdown]
# ## By Lane

# %%
lane_margin = margin_df.groupby(['Shipping City','Warehouse City','user_name']).aggregate({
    'awb':'count',
    'Shipment Charges':'sum',
    'total_cost':'sum'
}).reset_index()
lane_margin.head()
# Out:
#   Shipping City Warehouse City                user_name    awb  \
# 0     Bangalore      Bangalore    ANS Digital Pvt. Ltd.     88
# 1     Bangalore      Bangalore               Bebodywise   5415
# 2     Bangalore      Bangalore  Blitz NDD - Bags & Kits   1310
# 3     Bangalore      Bangalore                 Cureskin    822
# 4     Bangalore      Bangalore                Decathlon  10483
#
#    Shipment Charges     total_cost
# 0         26555.905    5373.674909
# 1        207775.450  232312.950818
# 2         63572.000   69319.791931
# 3         57069.030   42731.159746
# 4        903643.000  509443.670283

# %%
lane_margin.to_excel('lane_margin.xlsx',index=False)

# %%
lane_margin_city = margin_df.groupby(['Shipping City','Warehouse City']).aggregate({
    'awb':'count',
    'Shipment Charges':'sum',
    'total_cost':'sum'
}).reset_index()
lane_margin_city.to_excel('lane_margin_city.xlsx',index=False)
# Out:
# 2024-05-29 06:00:00,437| ERROR   | Socket exception: Connection reset by peer (54)
# 2024-05-29 06:00:00,492| ERROR   | Socket exception: Connection reset by peer (54)
